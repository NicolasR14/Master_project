# %%
import matplotlib.pyplot as plt
import numpy as np
def plot_history(path,learning_rate,learning_rate2,k):
    last_values = {i:[] for i in ['accuracy','val_accuracy','test_accuracy','loss','val_loss','test_loss']}
    for metric in ['accuracy','loss']:
        for i in range(k):
            values = np.load(f"{path}history_{i}_{learning_rate}_{learning_rate2}_{metric}.npy")
            val_values = np.load(f"{path}history_{i}_{learning_rate}_{learning_rate2}_val_{metric}.npy")
            last_values[f"{metric}"].append(values[-1])
            last_values[f"val_{metric}"].append(val_values[-1])
            last_values[f"test_{metric}"].append(np.load(f"value_{i}_{learning_rate}_{learning_rate2}_test_{metric}.npy"))

            plt.plot(values,'tab:blue')
            plt.plot(val_values,'tab:orange')

        plt.title(f"model {metric}")
        plt.ylabel(metric)
        plt.xlabel('epoch')
        if(metric=='accuracy'):
            plt.ylim([0.6,1])
        else:
            plt.ylim([0,1])
        plt.legend(['train', 'val'], loc='upper left')
        plt.show()

    for metric in ['accuracy','val_accuracy','loss','val_loss']:
        print(f"Moyenne {metric} : {np.mean(last_values[metric])}")

# %%
path = 'k=4_2e-05_1e-05/'
learning_rate= '2e-05'
learning_rate2='1e-05'
k=4

plot_history(optimizer,path,learning_rate,learning_rate2,k)

path = 'k=3_2e-05_1e-05/'
learning_rate= '2e-05'
learning_rate2='1e-05'
k=3

plot_history(optimizer,path,learning_rate,learning_rate2,k)
# Out:
# Moyenne accuracy : 0.9986026436090469
# Moyenne val_accuracy : 0.8874470740556717
# Moyenne loss : 0.009040375705808401
# Moyenne val_loss : 0.43668176233768463
# Moyenne accuracy : 0.9960079789161682
# Moyenne val_accuracy : 0.8578842480977377
# Moyenne loss : 0.01520290800059835
# Moyenne val_loss : 0.5591059724489847
