# %%
import numpy as np
import matplotlib.pyplot as plt
history = []
for k in range(5):
    plt.plot(np.concatenate((np.load(f'./history/history_{k}.npy',allow_pickle='TRUE').item()['accuracy'],np.load(f'./history/history_{k}_fine_tuning.npy',allow_pickle='TRUE').item()['accuracy']),axis=0))
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
len(history)
# Out:
# 5
