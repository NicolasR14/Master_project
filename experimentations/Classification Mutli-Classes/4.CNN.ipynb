# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense
from tensorflow.keras.optimizers import Adam,RMSprop
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
import sys
sys.path.append("..")
from common_functions import image_data_generation

# %%
dataset_path = '../images/raw_pollub/'
params = {'dim': (100,100),
          'batch_size': 64,
          'n_classes': 3,
          'n_channels': 3
        }
X,y_categorical,y = image_data_generation(dataset_path,params)

# %%
# StratifiedKFold with k folds
k = 3
skf = StratifiedKFold(n_splits=k)

# %%
learning_rate=2e-5
learning_rate2=5e-6

# %%
# Liste pour stocker les scores de validation
scores = {i:{'history':None,'history_fine_tuning':None,'score_test':None,'confusion_matrix':None} for i in range(k)}

def eval_cnn(i,train_index,val_test_index):
    #Train dataset
    X_train = X[train_index]
    y_train = y[train_index]

    #Validation and test dataset
    skf2 = StratifiedKFold(n_splits=2)
    test_index,val_index = next(skf2.split(X[val_test_index], y[val_test_index]))
    X_val = X[val_test_index][val_index]
    y_val = y[val_test_index][val_index]
    X_test = X[val_test_index][test_index]
    y_test = y[val_test_index][test_index]

    y_train = keras.utils.to_categorical(y_train, num_classes=params['n_classes'])
    y_val = keras.utils.to_categorical(y_val, num_classes=params['n_classes'])
    y_test = keras.utils.to_categorical(y_test, num_classes=params['n_classes'])

    #VGG16 model for feature extraction
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(params['dim'][0], params['dim'][1],params['n_channels']))

    #Freeze the layers of the convolutional base
    for layer in base_model.layers:
        layer.trainable = False

    #create the top layers for feature extraction
    model = Sequential()
    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(params['n_classes'], activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])

    #Train model
    print(f'Fold {i}')
    scores[i]['history'] = model.fit(x=X_train,y=y_train,validation_data=(X_val,y_val),epochs=50)

    #Unfreeze the upper layers of the convolutional base
    for layer in model.layers[0].layers[15:]:
        layer.trainable = True
    
    #Compile the model for fine-tuning
    model.compile(optimizer=Adam(learning_rate=learning_rate2), loss='categorical_crossentropy', metrics=['accuracy'])

    #Train model fine tuning
    print(f'Fold {i} fine tuning')
    scores[i]['history_fine_tuning'] = model.fit(x=X_train,y=y_train,validation_data=(X_val,y_val),epochs=10)

    scores[i]['score_test'] = model.evaluate(X_test, y_test)
    y_pred = model.predict(X_test)
    scores[i]['confusion_matrix'] = tf.math.confusion_matrix(np.argmax(y_test,axis=1),np.argmax(y_pred,axis=1))
    return

# %%
#Cross-validation
for i, (train_index, val_test_index) in enumerate(skf.split(X, y)):
    eval_cnn(i,train_index,val_test_index)
# Out:
# Fold 3
# Epoch 1/50
# 118/118 [==============================] - 17s 103ms/step - loss: 0.6432 - accuracy: 0.7390 - val_loss: 0.4458 - val_accuracy: 0.8658
# Epoch 2/50
# 118/118 [==============================] - 9s 76ms/step - loss: 0.3984 - accuracy: 0.8997 - val_loss: 0.3724 - val_accuracy: 0.9026
# Epoch 3/50
# 118/118 [==============================] - 9s 76ms/step - loss: 0.3417 - accuracy: 0.9117 - val_loss: 0.3355 - val_accuracy: 0.8802
# Epoch 4/50
# 118/118 [==============================] - 9s 75ms/step - loss: 0.2997 - accuracy: 0.9202 - val_loss: 0.2979 - val_accuracy: 0.9010
# Epoch 5/50
# 118/118 [==============================] - 9s 76ms/step - loss: 0.2706 - accuracy: 0.9236 - val_loss: 0.2687 - val_accuracy: 0.9105
# Epoch 6/50
# 118/118 [==============================] - 9s 76ms/step - loss: 0.2461 - accuracy: 0.9305 - val_loss: 0.2662 - val_accuracy: 0.8850
# Epoch 7/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.2268 - accuracy: 0.9324 - val_loss: 0.2309 - val_accuracy: 0.9233
# Epoch 8/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.2105 - accuracy: 0.9369 - val_loss: 0.2215 - val_accuracy: 0.9137
# Epoch 9/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1965 - accuracy: 0.9436 - val_loss: 0.1907 - val_accuracy: 0.9569
# Epoch 10/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.1838 - accuracy: 0.9462 - val_loss: 0.1740 - val_accuracy: 0.9744
# Epoch 11/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1741 - accuracy: 0.9513 - val_loss: 0.1658 - val_accuracy: 0.9712
# Epoch 12/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1645 - accuracy: 0.9540 - val_loss: 0.1531 - val_accuracy: 0.9824
# Epoch 13/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1559 - accuracy: 0.9561 - val_loss: 0.1561 - val_accuracy: 0.9633
# Epoch 14/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1484 - accuracy: 0.9582 - val_loss: 0.1502 - val_accuracy: 0.9633
# Epoch 15/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1412 - accuracy: 0.9625 - val_loss: 0.1238 - val_accuracy: 0.9856
# Epoch 16/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1371 - accuracy: 0.9593 - val_loss: 0.1195 - val_accuracy: 0.9856
# Epoch 17/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.1298 - accuracy: 0.9651 - val_loss: 0.1274 - val_accuracy: 0.9712
# Epoch 18/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.1241 - accuracy: 0.9662 - val_loss: 0.1222 - val_accuracy: 0.9728
# Epoch 19/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.1195 - accuracy: 0.9675 - val_loss: 0.1089 - val_accuracy: 0.9856
# Epoch 20/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.1143 - accuracy: 0.9707 - val_loss: 0.1171 - val_accuracy: 0.9712
# Epoch 21/50
# 118/118 [==============================] - 10s 81ms/step - loss: 0.1104 - accuracy: 0.9702 - val_loss: 0.1036 - val_accuracy: 0.9792
# Epoch 22/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.1059 - accuracy: 0.9721 - val_loss: 0.0980 - val_accuracy: 0.9840
# Epoch 23/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.1021 - accuracy: 0.9753 - val_loss: 0.0939 - val_accuracy: 0.9856
# Epoch 24/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0989 - accuracy: 0.9742 - val_loss: 0.0950 - val_accuracy: 0.9776
# Epoch 25/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0950 - accuracy: 0.9750 - val_loss: 0.0819 - val_accuracy: 0.9936
# Epoch 26/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0914 - accuracy: 0.9776 - val_loss: 0.0806 - val_accuracy: 0.9936
# Epoch 27/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0893 - accuracy: 0.9790 - val_loss: 0.0728 - val_accuracy: 0.9936
# Epoch 28/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0866 - accuracy: 0.9774 - val_loss: 0.0679 - val_accuracy: 0.9936
# Epoch 29/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0822 - accuracy: 0.9800 - val_loss: 0.0816 - val_accuracy: 0.9808
# Epoch 30/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0795 - accuracy: 0.9814 - val_loss: 0.0626 - val_accuracy: 0.9968
# Epoch 31/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.0777 - accuracy: 0.9827 - val_loss: 0.0689 - val_accuracy: 0.9952
# Epoch 32/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0746 - accuracy: 0.9835 - val_loss: 0.0569 - val_accuracy: 0.9968
# Epoch 33/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0717 - accuracy: 0.9838 - val_loss: 0.0593 - val_accuracy: 0.9952
# Epoch 34/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0694 - accuracy: 0.9848 - val_loss: 0.0664 - val_accuracy: 0.9936
# Epoch 35/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0673 - accuracy: 0.9851 - val_loss: 0.0576 - val_accuracy: 0.9952
# Epoch 36/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0651 - accuracy: 0.9851 - val_loss: 0.0499 - val_accuracy: 0.9968
# Epoch 37/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0627 - accuracy: 0.9875 - val_loss: 0.0497 - val_accuracy: 0.9968
# Epoch 38/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0618 - accuracy: 0.9859 - val_loss: 0.0478 - val_accuracy: 0.9968
# Epoch 39/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0586 - accuracy: 0.9878 - val_loss: 0.0480 - val_accuracy: 0.9952
# Epoch 40/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0571 - accuracy: 0.9872 - val_loss: 0.0637 - val_accuracy: 0.9888
# Epoch 41/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0546 - accuracy: 0.9891 - val_loss: 0.0442 - val_accuracy: 0.9968
# Epoch 42/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0544 - accuracy: 0.9883 - val_loss: 0.0498 - val_accuracy: 0.9968
# Epoch 43/50
# 118/118 [==============================] - 9s 80ms/step - loss: 0.0521 - accuracy: 0.9878 - val_loss: 0.0508 - val_accuracy: 0.9936
# Epoch 44/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.0499 - accuracy: 0.9891 - val_loss: 0.0375 - val_accuracy: 0.9984
# Epoch 45/50
# 118/118 [==============================] - 9s 77ms/step - loss: 0.0484 - accuracy: 0.9896 - val_loss: 0.0405 - val_accuracy: 0.9968
# Epoch 46/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0469 - accuracy: 0.9899 - val_loss: 0.0427 - val_accuracy: 0.9968
# Epoch 47/50
# 118/118 [==============================] - 9s 78ms/step - loss: 0.0451 - accuracy: 0.9912 - val_loss: 0.0337 - val_accuracy: 0.9984
# Epoch 48/50
# 118/118 [==============================] - 10s 82ms/step - loss: 0.0448 - accuracy: 0.9907 - val_loss: 0.0361 - val_accuracy: 0.9984
# Epoch 49/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0426 - accuracy: 0.9910 - val_loss: 0.0313 - val_accuracy: 0.9984
# Epoch 50/50
# 118/118 [==============================] - 9s 79ms/step - loss: 0.0409 - accuracy: 0.9923 - val_loss: 0.0327 - val_accuracy: 0.9984
# Fold 3 fine tuning
# Epoch 1/10
# 118/118 [==============================] - 14s 106ms/step - loss: 0.0210 - accuracy: 0.9960 - val_loss: 0.0085 - val_accuracy: 0.9984
# Epoch 2/10
# 118/118 [==============================] - 12s 99ms/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 0.0163 - val_accuracy: 0.9984
# Epoch 3/10
# 118/118 [==============================] - 12s 100ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 4/10
# 118/118 [==============================] - 12s 99ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 5/10
# 118/118 [==============================] - 12s 100ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 6/10
# 118/118 [==============================] - 12s 100ms/step - loss: 8.0099e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 7/10
# 118/118 [==============================] - 12s 100ms/step - loss: 6.2638e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 8/10
# 118/118 [==============================] - 12s 99ms/step - loss: 4.5928e-04 - accuracy: 1.0000 - val_loss: 6.0747e-04 - val_accuracy: 1.0000
# Epoch 9/10
# 118/118 [==============================] - 12s 100ms/step - loss: 3.5659e-04 - accuracy: 1.0000 - val_loss: 4.2629e-04 - val_accuracy: 1.0000
# Epoch 10/10
# 118/118 [==============================] - 12s 100ms/step - loss: 2.8892e-04 - accuracy: 1.0000 - val_loss: 3.3367e-04 - val_accuracy: 1.0000
# 20/20 [==============================] - 1s 66ms/step - loss: 0.0034 - accuracy: 1.0000
# 20/20 [==============================] - 1s 62ms/step

# %%
#Save results
import os
path = 'Results/'
optimizer='raw_Adam'
output_path = path + f"{optimizer}_k={k}_{learning_rate}_{learning_rate2}"
if not os.path.exists(output_path):
    os.makedirs(output_path)
for i in range(k):
    for metric in ['accuracy','val_accuracy','loss','val_loss']:
        np.save(f"{output_path}/history_{i}_{learning_rate}_{learning_rate2}_{metric}.npy",np.concatenate((scores[i]['history'].history[metric],scores[i]['history_fine_tuning'].history[metric])))
    for j,metric in enumerate(['test_loss','test_accuracy']):
        np.save(f"{output_path}/value_{i}_{learning_rate}_{learning_rate2}_{metric}.npy",scores[i]['score_test'][j])
    np.save(f"{output_path}/value_{i}_{learning_rate}_{learning_rate2}_confusion_matrix.npy",scores[i]['confusion_matrix'])
