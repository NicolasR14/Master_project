# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_text
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
import sys
sys.path.append("..")
from common_functions import HSV_features_generation

# %%
def eval_decision_tree(X,y,max_depth,k,min_samples_split=2, min_samples_leaf=1,show_tree=False):
    # Initialize lists to store the accuracy scores, features weights and confusion matrix
    accuracy_scores = []
    val_accuracy_scores = []
    test_accuracy_scores = []
    features_weights = []
    confusion_matrixs = []
    val_confusion_matrixs = []
    test_confusion_matrixs = []


    # StratifiedKFold with k folds
    skf = StratifiedKFold(n_splits=k)

    for i, (train_index, val_test_index) in enumerate(skf.split(X, y)):
        if(show_tree):
            print(f"Fold {i}:")
        #Train dataset
        X_train = X.iloc[train_index]
        y_train = y[train_index]

        #Validation and test dataset
        skf2 = StratifiedKFold(n_splits=2)
        test_index,val_index = next(skf2.split(X.iloc[val_test_index], y[val_test_index]))
        X_val = X.iloc[val_test_index].iloc[val_index]
        y_val = y[val_test_index][val_index]
        X_test = X.iloc[val_test_index].iloc[test_index]
        y_test = y[val_test_index][test_index]

        #Decision tree init
        decision_tree = DecisionTreeClassifier(random_state=0, max_depth=max_depth, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
        
        #Decision tree train
        decision_tree.fit(X_train, y_train)

        #Predictions
        y_train_pred = decision_tree.predict(X_train) #pour récupérer y_train_pred
        y_val_pred = decision_tree.predict(X_val)
        y_test_pred = decision_tree.predict(X_test)

        #Accuracy score
        accuracy = metrics.accuracy_score(y_train, y_train_pred)
        val_accuracy = metrics.accuracy_score(y_val, y_val_pred)
        test_accuracy = metrics.accuracy_score(y_test, y_test_pred)

        #Confusion matrix
        confusion_mat = confusion_matrix(y_train, y_train_pred)
        confusion_mat_val = confusion_matrix(y_val, y_val_pred)
        confusion_mat_test = confusion_matrix(y_test, y_test_pred)

        if(show_tree):
            print(f'Fold {i} accuracy : {accuracy}, val accuracy :{val_accuracy},test accuracy :{test_accuracy}')

        #Append the accuracy score to the list
        accuracy_scores.append(accuracy)
        val_accuracy_scores.append(val_accuracy)
        test_accuracy_scores.append(test_accuracy)
        features_weights.append(decision_tree.feature_importances_) 
        confusion_matrixs.append(confusion_mat)
        val_confusion_matrixs.append(confusion_mat_val)
        test_confusion_matrixs.append(confusion_mat_test)

        if(show_tree):
            #Print features weights
            print(f"Poids caractéristiques : {decision_tree.feature_importances_}")
            r = export_text(decision_tree, feature_names=X_train.columns.values.tolist())
            #Plot tree
            print(r,'\n')


    if(show_tree):
        # Compute the average accuracy across all folds
        print('-------------------')
        print(f"Train accuracy : {np.mean(accuracy_scores)}")
        print(f"Val accuracy : {np.mean(val_accuracy_scores)}")
        print(f"Test accuracy : {np.mean(test_accuracy_scores)}")
    features_weights = np.array(features_weights)
    average_weights = [features_weights[:,i].mean() for i in range(6)]
    if(show_tree):
        print('Average feature weights',average_weights)

    # Filter weights to not show null values
    filtered_weights = [w for w in average_weights if w != 0]
    filtered_feature_names = [name for name, w in zip(['H_mean','H_std','S_mean','S_std','V_mean','V_std'], average_weights) if w != 0]
    if(show_tree):
        plt.pie(filtered_weights, labels=filtered_feature_names, autopct='%1.1f%%')
        plt.show()

        labels_x=['normal','excess','insufficient']
        labels_y = labels_x

        fig, ax = plt.subplots(figsize=(4, 3))
        ax.set_xlabel('Prédiction')
        ax.set_ylabel('Vraie étiquette')
        ax.set_title('Matrice de confusion')
        print('Average confusion matrix')
        sns.heatmap(np.mean(confusion_matrixs, axis=0), annot=True, cmap="Blues", ax=ax, fmt='.0f', xticklabels=labels_x, yticklabels=labels_y)
        plt.show()

        fig, ax = plt.subplots(figsize=(4, 3))
        ax.set_xlabel('Prédiction')
        ax.set_ylabel('Vraie étiquette')
        ax.set_title('Matrice de confusion val')
        print('Average val confusion matrix')
        sns.heatmap(np.mean(val_confusion_matrixs, axis=0), annot=True, cmap="Oranges", ax=ax, fmt='.0f', xticklabels=labels_x, yticklabels=labels_y)
        plt.show()

        fig, ax = plt.subplots(figsize=(4, 3))
        ax.set_xlabel('Prédiction')
        ax.set_ylabel('Vraie étiquette')
        ax.set_title('Matrice de confusion test')
        print('Average test confusion matrix')
        sns.heatmap(np.mean(test_confusion_matrixs, axis=0), annot=True, cmap="Greens", ax=ax, fmt='.0f', xticklabels=labels_x, yticklabels=labels_y)
        plt.show()

    return np.mean(accuracy_scores),np.mean(val_accuracy_scores),np.mean(test_accuracy_scores),np.array(average_weights)

# %%
#Generation data
X,y = HSV_features_generation('../images/raw_pollub/')

# %%
acc_train = []
acc_val = []
acc_test = []

for k in range(2,5+1):
    accuracies = []
    val_accuracies = []
    test_accuracies = []
    for max_depth in range(2,6+1):
        accuracy,val_accuracy,test_accuracy,features_weights = eval_decision_tree(X,y,max_depth,k)
        accuracies.append(accuracy)
        val_accuracies.append(val_accuracy)
        test_accuracies.append(test_accuracy)
    acc_train.append(accuracies)
    acc_val.append(val_accuracies)
    acc_test.append(test_accuracies)

# %%
sns.set(font_scale=0.7)
mat_acc_train = np.array(acc_train)
labels_x = range(2,7)
labels_y = range(2,6)
plt.figure(figsize = (3,3))
sns.heatmap(mat_acc_train, annot=True, cmap="Blues", fmt='.3f', xticklabels=labels_x, yticklabels=labels_y)
plt.xlabel('Max depth')
plt.ylabel('Nombre de plis k')
plt.title('Précision moyenne train,\nvariation de k et max_depth')
plt.show()

# %%
mat_acc_val = np.array(acc_val)
labels_x = range(2,7)
labels_y = range(2,6)
plt.figure(figsize = (3,3))
sns.heatmap(mat_acc_val, annot=True, cmap="Oranges", fmt='.3f', xticklabels=labels_x, yticklabels=labels_y)
plt.xlabel('Max depth')
plt.ylabel('Nombre de plis k')
plt.title('Précision moyenne val,\nvariation de k et max_depth')
plt.show()

# %%
mat_acc_test = np.array(acc_test)
labels_x = range(2,7)
labels_y = range(2,6)
plt.figure(figsize = (3,3))
sns.heatmap(mat_acc_test, annot=True, cmap="Greens", fmt='.3f', xticklabels=labels_x, yticklabels=labels_y)
plt.xlabel('Max depth')
plt.ylabel('Nombre de plis k')
plt.title('Précision moyenne test,\nvariation de k et max_depth')
plt.show()

# %%
acc_train = []
acc_val = []
acc_test = []
k = 5
max_depth = 6
for min_samples_split in range(2,20+1):
    accuracies = []
    val_accuracies = []
    test_accuracies = []
    for min_samples_leaf in range(1,20+1):
        accuracy,val_accuracy,test_accuracy,features_weights = eval_decision_tree(X,y,max_depth,k,min_samples_split,min_samples_leaf)
        accuracies.append(accuracy)
        val_accuracies.append(val_accuracy)
        test_accuracies.append(test_accuracy)
    acc_train.append(accuracies)
    acc_val.append(val_accuracies)
    acc_test.append(test_accuracies)

# %%
sns.set(font_scale=1)
mat_acc_train = np.array(acc_train)
labels_x = range(1,20+1)
labels_y = range(2,20+1)
plt.figure(figsize = (3,3))
sns.heatmap(mat_acc_train,cmap="Blues", xticklabels=labels_x, yticklabels=labels_y)
plt.xlabel('min_samples_leaf')
plt.ylabel('min_samples_split')
plt.title('Précision moyenne train, variation de\nmin_samples_leaf et min_samples_split')
plt.show()

# %%
mat_acc_val = np.array(acc_val)
labels_x = range(1,20+1)
labels_y = range(2,20+1)
plt.figure(figsize = (3,3))
sns.heatmap(mat_acc_val, cmap="Oranges", xticklabels=labels_x, yticklabels=labels_y)
plt.xlabel('min_samples_leaf')
plt.ylabel('min_samples_split')
plt.title('Précision moyenne val, variation de\nmin_samples_leaf et min_samples_split')
plt.show()

# %%
mat_acc_test = np.array(acc_test)
labels_x = range(1,20+1)
labels_y = range(2,20+1)
plt.figure(figsize = (3,3))
sns.heatmap(mat_acc_test,cmap="Greens", xticklabels=labels_x, yticklabels=labels_y)
plt.xlabel('min_samples_leaf')
plt.ylabel('min_samples_split')
plt.title('Précision moyenne test, variation de\nmin_samples_leaf et min_samples_split')
plt.show()

# %%
eval_decision_tree(X,y,6,4,min_samples_split=2, min_samples_leaf=14,show_tree=True)
# Out:
# Fold 0:
# Fold 0 accuracy : 0.9608730369976045, val accuracy :0.9154704944178629,test accuracy :0.9712460063897763
# Poids caractéristiques : [0.10927836 0.54871726 0.0643671  0.27505591 0.         0.00258137]
# |--- H_std <= 39.91
# |   |--- S_std <= 84.25
# |   |   |--- H_mean <= 15.02
# |   |   |   |--- S_std <= 83.46
# |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  83.46
# |   |   |   |   |--- H_mean <= 14.82
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- H_mean >  14.82
# |   |   |   |   |   |--- S_mean <= 142.07
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  142.07
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- H_mean >  15.02
# |   |   |   |--- H_std <= 34.78
# |   |   |   |   |--- S_std <= 83.70
# |   |   |   |   |   |--- S_std <= 83.52
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  83.52
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  83.70
# |   |   |   |   |   |--- S_mean <= 142.28
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  142.28
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- H_std >  34.78
# |   |   |   |   |--- H_std <= 34.96
# |   |   |   |   |   |--- S_std <= 83.15
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  83.15
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- H_std >  34.96
# |   |   |   |   |   |--- S_std <= 84.07
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  84.07
# |   |   |   |   |   |   |--- class: 2
# |   |--- S_std >  84.25
# |   |   |--- H_mean <= 15.22
# |   |   |   |--- S_std <= 85.00
# |   |   |   |   |--- S_mean <= 144.13
# |   |   |   |   |   |--- S_mean <= 143.64
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  143.64
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  144.13
# |   |   |   |   |   |--- V_std <= 30.29
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- V_std >  30.29
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  85.00
# |   |   |   |   |--- S_mean <= 145.69
# |   |   |   |   |   |--- S_std <= 85.12
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  85.12
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  145.69
# |   |   |   |   |   |--- S_std <= 85.47
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  85.47
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- H_mean >  15.22
# |   |   |   |--- S_std <= 85.61
# |   |   |   |   |--- S_mean <= 144.16
# |   |   |   |   |   |--- S_std <= 84.42
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  84.42
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  144.16
# |   |   |   |   |   |--- S_std <= 84.97
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  84.97
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  85.61
# |   |   |   |   |--- S_std <= 85.75
# |   |   |   |   |   |--- S_mean <= 146.46
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  146.46
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  85.75
# |   |   |   |   |   |--- S_std <= 85.84
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  85.84
# |   |   |   |   |   |   |--- class: 1
# |--- H_std >  39.91
# |   |--- class: 0
#
#
# Fold 1:
# Fold 1 accuracy : 0.9558158104870907, val accuracy :0.9553429027113237,test accuracy :0.9584664536741214
# Poids caractéristiques : [0.10872249 0.55857458 0.07197226 0.23991821 0.         0.02081247]
# |--- H_std <= 39.85
# |   |--- S_std <= 84.82
# |   |   |--- H_mean <= 15.08
# |   |   |   |--- S_std <= 83.71
# |   |   |   |   |--- S_std <= 83.46
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  83.46
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  83.71
# |   |   |   |   |--- S_mean <= 143.18
# |   |   |   |   |   |--- S_std <= 84.31
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  84.31
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  143.18
# |   |   |   |   |   |--- V_std <= 27.40
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- V_std >  27.40
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- H_mean >  15.08
# |   |   |   |--- V_std <= 39.14
# |   |   |   |   |--- S_std <= 84.30
# |   |   |   |   |   |--- S_std <= 83.73
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  83.73
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  84.30
# |   |   |   |   |   |--- S_mean <= 143.87
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  143.87
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- V_std >  39.14
# |   |   |   |   |--- class: 1
# |   |--- S_std >  84.82
# |   |   |--- H_mean <= 15.38
# |   |   |   |--- H_mean <= 15.15
# |   |   |   |   |--- S_std <= 85.12
# |   |   |   |   |   |--- S_mean <= 144.66
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  144.66
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  85.12
# |   |   |   |   |   |--- S_mean <= 145.79
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  145.79
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- H_mean >  15.15
# |   |   |   |   |--- V_std <= 38.01
# |   |   |   |   |   |--- S_mean <= 144.91
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  144.91
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- V_std >  38.01
# |   |   |   |   |   |--- H_mean <= 15.29
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- H_mean >  15.29
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- H_mean >  15.38
# |   |   |   |--- S_std <= 85.67
# |   |   |   |   |--- S_mean <= 145.81
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  145.81
# |   |   |   |   |   |--- S_std <= 85.45
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  85.45
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  85.67
# |   |   |   |   |--- S_std <= 86.01
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_std >  86.01
# |   |   |   |   |   |--- class: 1
# |--- H_std >  39.85
# |   |--- class: 0
#
#
# Fold 2:
# Fold 2 accuracy : 0.9630122405534859, val accuracy :0.9600638977635783,test accuracy :0.8961661341853036
# Poids caractéristiques : [0.07943648 0.5448018  0.08642755 0.27544105 0.00146468 0.01242845]
# |--- H_std <= 39.91
# |   |--- S_std <= 84.57
# |   |   |--- H_mean <= 15.02
# |   |   |   |--- S_std <= 83.48
# |   |   |   |   |--- H_std <= 34.47
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- H_std >  34.47
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  83.48
# |   |   |   |   |--- S_mean <= 142.89
# |   |   |   |   |   |--- S_std <= 83.78
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  83.78
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  142.89
# |   |   |   |   |   |--- S_std <= 84.40
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  84.40
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- H_mean >  15.02
# |   |   |   |--- S_std <= 83.70
# |   |   |   |   |--- S_std <= 83.40
# |   |   |   |   |   |--- S_std <= 83.16
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  83.16
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  83.40
# |   |   |   |   |   |--- S_mean <= 142.04
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_mean >  142.04
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  83.70
# |   |   |   |   |--- S_mean <= 143.06
# |   |   |   |   |   |--- S_std <= 83.95
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  83.95
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  143.06
# |   |   |   |   |   |--- S_mean <= 143.34
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_mean >  143.34
# |   |   |   |   |   |   |--- class: 2
# |   |--- S_std >  84.57
# |   |   |--- H_mean <= 15.31
# |   |   |   |--- S_std <= 84.95
# |   |   |   |   |--- S_mean <= 144.17
# |   |   |   |   |   |--- S_mean <= 143.85
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  143.85
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  144.17
# |   |   |   |   |   |--- S_std <= 84.82
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  84.82
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  84.95
# |   |   |   |   |--- H_mean <= 15.29
# |   |   |   |   |   |--- H_mean <= 15.06
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- H_mean >  15.06
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- H_mean >  15.29
# |   |   |   |   |   |--- class: 1
# |   |   |--- H_mean >  15.31
# |   |   |   |--- V_std <= 44.89
# |   |   |   |   |--- S_mean <= 145.25
# |   |   |   |   |   |--- V_mean <= 37.75
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- V_mean >  37.75
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  145.25
# |   |   |   |   |   |--- S_std <= 85.69
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  85.69
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- V_std >  44.89
# |   |   |   |   |--- S_std <= 85.69
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  85.69
# |   |   |   |   |   |--- class: 1
# |--- H_std >  39.91
# |   |--- class: 0
#
#
# Fold 3:
# Fold 3 accuracy : 0.9606173496540713, val accuracy :0.952076677316294,test accuracy :0.9297124600638977
# Poids caractéristiques : [0.09248553 0.54803754 0.07501052 0.25218663 0.02476295 0.00751684]
# |--- H_std <= 39.91
# |   |--- S_std <= 84.30
# |   |   |--- H_mean <= 14.98
# |   |   |   |--- S_std <= 83.46
# |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  83.46
# |   |   |   |   |--- S_mean <= 142.35
# |   |   |   |   |   |--- S_std <= 83.76
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  83.76
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  142.35
# |   |   |   |   |   |--- class: 2
# |   |   |--- H_mean >  14.98
# |   |   |   |--- S_std <= 83.74
# |   |   |   |   |--- S_std <= 83.40
# |   |   |   |   |   |--- S_std <= 83.16
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  83.16
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_std >  83.40
# |   |   |   |   |   |--- S_mean <= 141.84
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_mean >  141.84
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  83.74
# |   |   |   |   |--- S_mean <= 142.67
# |   |   |   |   |   |--- V_std <= 32.49
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- V_std >  32.49
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- S_mean >  142.67
# |   |   |   |   |   |--- S_mean <= 143.42
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_mean >  143.42
# |   |   |   |   |   |   |--- class: 2
# |   |--- S_std >  84.30
# |   |   |--- H_mean <= 15.22
# |   |   |   |--- S_std <= 84.96
# |   |   |   |   |--- S_mean <= 143.88
# |   |   |   |   |   |--- S_mean <= 143.63
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_mean >  143.63
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  143.88
# |   |   |   |   |   |--- V_std <= 28.32
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- V_std >  28.32
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- S_std >  84.96
# |   |   |   |   |--- H_mean <= 15.05
# |   |   |   |   |   |--- H_std <= 34.57
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- H_std >  34.57
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- H_mean >  15.05
# |   |   |   |   |   |--- V_std <= 38.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- V_std >  38.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- H_mean >  15.22
# |   |   |   |--- V_mean <= 43.07
# |   |   |   |   |--- S_mean <= 144.16
# |   |   |   |   |   |--- S_std <= 84.42
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- S_std >  84.42
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- S_mean >  144.16
# |   |   |   |   |   |--- S_std <= 84.97
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- S_std >  84.97
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- V_mean >  43.07
# |   |   |   |   |--- V_std <= 46.57
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- V_std >  46.57
# |   |   |   |   |   |--- class: 1
# |--- H_std >  39.91
# |   |--- class: 0
#
#
# -------------------
# Train accuracy : 0.960079609423063
# Val accuracy : 0.9457384930522647
# Test accuracy : 0.9388977635782747
# Average feature weights [0.09748071464530492, 0.5500327940136394, 0.0744443572524497, 0.26065044995087255, 0.006556905080031394, 0.010834779057702025]
# Average confusion matrix
# Average val confusion matrix
# Average test confusion matrix
# (0.960079609423063,
#  0.9457384930522647,
#  0.9388977635782747,
#  array([0.09748071, 0.55003279, 0.07444436, 0.26065045, 0.00655691,
#         0.01083478]))
